# %% [markdown]
# estructuras_Dataframe

# %% [markdown]
# Ejercicio 1:
#
# Realiza la práctica del notebook en GitHub " 03 EXAMINING DATA " (haz una copia y ejecuta los comandos con el mismo dataset county.txt). Este ejercicio consiste en observar las distintas posibilidades que ofrecen las diferentes librerías de visualización gráfica.
#
# https://github.com/BIDDL3/Examining-Data/blob/main/03%20EXAMINING%20DATA.ipynb

# %%
# importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
county = pd.read_csv('https://raw.githubusercontent.com/BIDDL3/Examining-Data/main/county.txt', sep='\t', encoding='utf-8')
county
# Out:
#                    name    state   pop2000  pop2010  fed_spend  poverty  \
# 0        Autauga County  Alabama   43671.0    54571   6.068095     10.6
# 1        Baldwin County  Alabama  140415.0   182265   6.139862     12.2
# 2        Barbour County  Alabama   29038.0    27457   8.752158     25.0
# 3           Bibb County  Alabama   20826.0    22915   7.122016     12.6
# 4         Blount County  Alabama   51024.0    57322   5.130910     13.4
# ...                 ...      ...       ...      ...        ...      ...
# 3138  Sweetwater County  Wyoming   37613.0    43806   5.062138      8.2
# 3139       Teton County  Wyoming   18251.0    21294   6.236968      8.2
# 3140       Uinta County  Wyoming   19742.0    21118   4.549105     12.1
# 3141    Washakie County  Wyoming    8289.0     8533   8.713817      5.6
# 3142      Weston County  Wyoming    6644.0     7208   6.694784      7.9
#
#       homeownership  multiunit  income  med_income
# 0              77.5        7.2   24568       53255
# ...

# %%
# Ver los tipos de datos:
county.dtypes
# Out:
# name              object
# state             object
# pop2000          float64
# pop2010            int64
# fed_spend        float64
# poverty          float64
# homeownership    float64
# multiunit        float64
# income             int64
# med_income         int64
# dtype: object

# %%
# Ver el tamaño del Dataframe:
county.shape
# Out:
# (3143, 10)

# %%
# Ver las Columnas:
county.columns
# Out:
# Index(['name', 'state', 'pop2000', 'pop2010', 'fed_spend', 'poverty',
#        'homeownership', 'multiunit', 'income', 'med_income'],
#       dtype='object')

# %%
# Observar los registros únicos de la varible 'state':
county.state.unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
# Conteo de los registos únicos:
county.state.nunique()
# Out:
# 51

# %%
# Se redondea los valores al decimal más cercano:
county.describe().round(3)
# Out:
#            pop2000      pop2010  fed_spend   poverty  homeownership  \
# count     3140.000     3143.000   3139.000  3143.000       3143.000
# mean     89623.445    98232.752      9.991    15.499         73.264
# std     292504.848   312901.202      7.567     6.384          7.832
# min         67.000       82.000      0.000     0.000          0.000
# 25%      11209.750    11104.500      6.964    11.000         69.500
# 50%      24608.000    25857.000      8.669    14.700         74.600
# 75%      61766.500    66699.000     10.857    19.000         78.400
# max    9519338.000  9818605.000    204.616    53.500         91.300
#
#        multiunit     income  med_income
# count   3143.000   3143.000    3143.000
# mean      12.325  22504.696   44270.299
# std        9.291   5408.668   11547.636
# min        0.000   7772.000   19351.000
# 25%        6.100  19030.000   36952.000
# 50%        9.700  21773.000   42445.000
# 75%       15.900  24813.500   49142.000
# ...

# %%
# Se saca la media de la variable 'pop2000':
county.pop2000.mean()
# Out:
# 89623.44490445859

# %%
# Creación Gráfico:
x = county.fed_spend
y = county.poverty
colors = 'Blue'
area = np.pi*5

plt.axis([-10, 100, 0, 60])

plt.scatter(x, y, s=area, c=colors, alpha=0.4, edgecolors='black')

plt.title('Federal Spending vs Poverty by County')
plt.ylabel('Federal Spending per Capita')
plt.xlabel('Poverty Rate (Percent)')
plt.show()

# %%
sns.pairplot(county, diag_kind='hist', plot_kws={'alpha': 0.2})

# %%
fig = plt.figure(figsize=(10,8))

ax1 = fig.add_subplot(2, 2, 1)

ax1.hist(county['multiunit'], bins=25)
plt.title('County - 2010 Population')
plt.ylabel('Frequency')
plt.xlabel('multi unit (%)')
# Out:
# Text(0.5, 0, 'multi unit (%)')

# %%
fig = plt.figure(figsize=(10,8))
ax2 = fig.add_subplot(2, 2, 2)

ax2.hist(county['income'], bins=25)

plt.title('2010 County Population')
plt.ylabel('Frequency')
plt.xlabel('Per Capita Income')
# Out:
# Text(0.5, 0, 'Per Capita Income')

# %%
fig = plt.figure(figsize=(10,8))

ax3 = fig.add_subplot(2, 2, 3)

ax3.hist(county['homeownership'], bins=25)
plt.title('2010 County Population')
plt.ylabel('Frequency')
plt.xlabel('Homeownership (%)')
# Out:
# Text(0.5, 0, 'Homeownership (%)')

# %%
fig = plt.figure(figsize=(10,8))
ax4 = fig.add_subplot(2, 2, 4)

ax4.hist(county['med_income'], bins=25)

plt.title('2010 County Population')
plt.ylabel('Frequency')
plt.xlabel('Median Household Imcome')

plt.tight_layout()

# %%
sns.set(style="whitegrid")
ax = sns.boxplot(x=county["med_income"], color='lightblue', fliersize=5,  orient='v', linewidth=1 , width=0.3)

# %%
sns.stripplot(x=county["med_income"], orient='v', color='darkblue')
# Out:
# <AxesSubplot: xlabel='med_income'>

# %%
sns.swarmplot(x=county["med_income"], orient='v', color='darkblue')
# Out:
# <AxesSubplot: xlabel='med_income'>

# %%
ax = sns.boxplot(y="med_income", data=county,  color='lightblue', fliersize=5,  orient='v', linewidth=1 , width=0.3)

# %%
ax = sns.swarmplot(y="med_income", data=county, color="darkblue", orient="v", size=4)

# %%
ax = sns.stripplot(y=county["med_income"], orient='v', color='darkblue', alpha= 0.5)

# %%
# Gráficar una variable númerica:

sns.boxplot(y="pop2000", data=county[county.pop2000 < 1000],  color='lightblue', fliersize=5,  orient='v', linewidth=1 , width=0.3)
# Out:
# <AxesSubplot: ylabel='pop2000'>

# %% [markdown]
# Ejercicio 2:
#
# Realiza las tareas de preprocesado y adecuación del Dataset que disponemos en el repositorio de GitHub  PRE-PROCESSING-FECHA con el objetivo de prepararlo y trabajarlo como dataframe para extraer información.
#
# https://github.com/BIDDL3/PRE-PROCESSING-DATA/blob/main/movies.dat
#
# •Importante
#
# El resultado final debe ser un dataframe con las variables de nombre de la película , año y género.  ¡También es importante quedarse con un solo género para cada película!

# %%
df_movies = pd.read_csv('movies.dat', sep ='::', encoding = 'latin-1', engine='python', header = None, names = ('Movie_id','Nombre','Genero'))
df_movies
# Out:
#       Movie_id                              Nombre  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 3878      3948             Meet the Parents (2000)
# 3879      3949          Requiem for a Dream (2000)
# 3880      3950                    Tigerland (2000)
# 3881      3951             Two Family House (2000)
# 3882      3952               Contender, The (2000)
#
#                             Genero
# 0      Animation|Children's|Comedy
# 1     Adventure|Children's|Fantasy
# 2                   Comedy|Romance
# 3                     Comedy|Drama
# 4                           Comedy
# ...                            ...
# 3878                        Comedy
# 3879                         Drama
# ...

# %%
Año = df_movies['Nombre'].str.slice(start=-5, stop=-1) # Separamos con un slice la información de los años
df_movies['Año'] = Año # Creamos una nueva columna en el dataset con la información obtenida
df_movies['Nombre'] = df_movies['Nombre'].str.slice(start=0, stop=-7) # Separamos con un slice el nombre de las películas
Genero = df_movies['Genero'].str.split(pat='|', n=1, expand=True)  # Separamos con un split el género de las películas
df_movies['Genero'] = Genero[0] # nos quedamos con el primer resultado/columna del dataset obtenido

# %%
df_movies  # dataset con la información organizada
# Out:
#       Movie_id                       Nombre     Genero   Año
# 0            1                    Toy Story  Animation  1995
# 1            2                      Jumanji  Adventure  1995
# 2            3             Grumpier Old Men     Comedy  1995
# 3            4            Waiting to Exhale     Comedy  1995
# 4            5  Father of the Bride Part II     Comedy  1995
# ...        ...                          ...        ...   ...
# 3878      3948             Meet the Parents     Comedy  2000
# 3879      3949          Requiem for a Dream      Drama  2000
# 3880      3950                    Tigerland      Drama  2000
# 3881      3951             Two Family House      Drama  2000
# 3882      3952               Contender, The      Drama  2000
#
# [3883 rows x 4 columns]

# %%
df_movies.dtypes  # vemos los tipos de datos
# Out:
# Movie_id     int64
# Nombre      object
# Genero      object
# Año         object
# dtype: object

# %%
df_movies.Año = df_movies.Año.astype('int64')  # pasamos a enteros la columna de año para poder graficar
df_movies.dtypes
# Out:
# Movie_id     int64
# Nombre      object
# Genero      object
# Año          int64
# dtype: object

# %% [markdown]
# Tenemos un dataset con dos variables categóricas nominales y dos numéricas discretas.

# %%
df_movies.duplicated().sum()  # vemos si hay registros duplicados
# Out:
# 0

# %%
df_movies.isnull().sum()  # vemos si tenemos nulos
# Out:
# Movie_id    0
# Nombre      0
# Genero      0
# Año         0
# dtype: int64

# %%
df_movies.isna().sum() # vemos si tenemos Nans
# Out:
# Movie_id    0
# Nombre      0
# Genero      0
# Año         0
# dtype: int64

# %%
df_movies.to_csv('movies.csv', index = False, sep ='\t', encoding='utf-8')  # lo dejamos preparado en un archivo .csv

# %% [markdown]
#  Ejercicio 3:
#
#  Muestra tu creatividad. ¿Qué crees relevante mostrar del Dataset " movies.dat " del ejercicio anterior?
#
#  Realiza una o dos representaciones gráficas y justifica tu elección.

# %% [markdown]
# •Evolución de la producción de peliculas en el tiempo:

# %%
fig, ax = plt.subplots(figsize = (20, 10))
sns.countplot(data=df_movies, x="Año");
plt.xticks(rotation=90);

# %% [markdown]
# Vemos que el crecimiento ha sido constante. Hubo una aceleración a finales de la década de los años setenta llegándose a triplicar la producción en la década de los noventa. Los años más productivos fueron desde 1995 a 1998 y a partir de aquí fue decayendo a la mitad en el año 2000.

# %% [markdown]
# • Estudio de los géneros más filmados:

# %%
fig, ax = plt.subplots(figsize = (20, 10))
sns.countplot(data=df_movies, x="Genero");
plt.xticks(rotation=90);

# %% [markdown]
# Drama y comedia son, con diferencia, los géneros más filmados. También destacan acción y horror. En menor producción western, misterio y cine negro y prácticamente inexistentes guerra, fantasía y musical.
